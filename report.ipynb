# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "none"

# %%
model_perf = pd.read_csv('performance/model_performance_all.csv')

grouped = model_perf.groupby('Dataset')

frames = {category : group for category, group in grouped}
df_CondMat = frames['data/CondMat.csv']
df_GenRel = frames['data/GenRel.csv']
df_ErdosReny = frames['data/ErdosRenyi.csv']
df_BarabasiAlbert = frames['data/BarabasiAlbert.csv']

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 20))
sns.barplot(data=df_CondMat, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][0])
sns.barplot(data=df_GenRel, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][1])
sns.barplot(data=df_BarabasiAlbert, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][2])
sns.barplot(data=df_ErdosReny, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][3])
axes[0][0].set_ylim(0.9, 1)
axes[0][1].set_ylim(0.9, 1)
axes[0][2].set_ylim(0.7, 1)
axes[0][3].set_ylim(0.9, 1)
axes[0][0].set_title('CondMat')
axes[0][1].set_title('GenRel')
axes[0][2].set_title('BarabasiAlbert')
axes[0][3].set_title('ErdoRenyi')
axes[0][0].legend(loc='lower right')
axes[0][1].legend(loc='lower right')
axes[0][2].legend(loc='lower right')
axes[0][3].legend(loc='lower right')
sns.barplot(data=df_CondMat, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][0])
sns.barplot(data=df_GenRel, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][1])
sns.barplot(data=df_BarabasiAlbert, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][2])
sns.barplot(data=df_ErdosReny, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][3])
axes[1][0].set_ylim(0.9, 1)
axes[1][1].set_ylim(0.9, 1)
axes[1][2].set_ylim(0.7, 1)
axes[1][3].set_ylim(0.9, 1)
axes[1][0].legend(loc='lower right')
axes[1][1].legend(loc='lower right')
axes[1][2].legend(loc='lower right')
axes[1][3].legend(loc='lower right')
fig.suptitle('Comparison of test and train accuracies across different models and datasets \n using all features', fontsize=16)

# %%
model_perf = pd.read_csv('performance/model_performance_without_shortest_path.csv')

grouped = model_perf.groupby('Dataset')

frames = {category : group for category, group in grouped}
df_CondMat = frames['data/CondMat.csv']
df_GenRel = frames['data/GenRel.csv']
df_ErdosReny = frames['data/ErdosRenyi.csv']
df_BarabasiAlbert = frames['data/BarabasiAlbert.csv']

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 20))
sns.barplot(data=df_CondMat, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][0])
sns.barplot(data=df_GenRel, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][1])
sns.barplot(data=df_BarabasiAlbert, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][2])
sns.barplot(data=df_ErdosReny, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][3])
axes[0][0].set_ylim(0.9, 1)
axes[0][1].set_ylim(0.9, 1)
axes[0][2].set_ylim(0.7, 1)
axes[0][3].set_ylim(0.9, 1)
axes[0][0].set_title('CondMat')
axes[0][1].set_title('GenRel')
axes[0][2].set_title('BarabasiAlbert')
axes[0][3].set_title('ErdoRenyi')
axes[0][0].legend(loc='lower right')
axes[0][1].legend(loc='lower right')
axes[0][2].legend(loc='lower right')
axes[0][3].legend(loc='lower right')
sns.barplot(data=df_CondMat, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][0])
sns.barplot(data=df_GenRel, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][1])
sns.barplot(data=df_BarabasiAlbert, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][2])
sns.barplot(data=df_ErdosReny, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][3])
axes[1][0].set_ylim(0.9, 1)
axes[1][1].set_ylim(0.9, 1)
axes[1][2].set_ylim(0.7, 1)
axes[1][3].set_ylim(0.9, 1)
axes[1][0].legend(loc='lower right')
axes[1][1].legend(loc='lower right')
axes[1][2].legend(loc='lower right')
axes[1][3].legend(loc='lower right')
fig.suptitle('Comparison of test and train accuracies across different models and datasets \n without shortest path feature', fontsize=16)

# %%
model_perf = pd.read_csv('performance/model_performance_without_ego.csv')

grouped = model_perf.groupby('Dataset')

frames = {category : group for category, group in grouped}
df_CondMat = frames['data/CondMat.csv']
df_GenRel = frames['data/GenRel.csv']
df_ErdosReny = frames['data/ErdosRenyi.csv']
df_BarabasiAlbert = frames['data/BarabasiAlbert.csv']

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 20))
sns.barplot(data=df_CondMat, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][0])
sns.barplot(data=df_GenRel, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][1])
sns.barplot(data=df_BarabasiAlbert, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][2])
sns.barplot(data=df_ErdosReny, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][3])
axes[0][0].set_ylim(0.9, 1)
axes[0][1].set_ylim(0.9, 1)
axes[0][2].set_ylim(0.7, 1)
axes[0][3].set_ylim(0.9, 1)
axes[0][0].set_title('CondMat')
axes[0][1].set_title('GenRel')
axes[0][2].set_title('BarabasiAlbert')
axes[0][3].set_title('ErdoRenyi')
axes[0][0].legend(loc='lower right')
axes[0][1].legend(loc='lower right')
axes[0][2].legend(loc='lower right')
axes[0][3].legend(loc='lower right')
sns.barplot(data=df_CondMat, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][0])
sns.barplot(data=df_GenRel, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][1])
sns.barplot(data=df_BarabasiAlbert, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][2])
sns.barplot(data=df_ErdosReny, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][3])
axes[1][0].set_ylim(0.9, 1)
axes[1][1].set_ylim(0.9, 1)
axes[1][2].set_ylim(0.7, 1)
axes[1][3].set_ylim(0.9, 1)
axes[1][0].legend(loc='lower right')
axes[1][1].legend(loc='lower right')
axes[1][2].legend(loc='lower right')
axes[1][3].legend(loc='lower right')
fig.suptitle('Comparison of test and train accuracies across different models and datasets \n without densities of ego networks features', fontsize=16)

# %%
model_perf = pd.read_csv('performance/model_performance_without_ego_and_shortest_path.csv')

grouped = model_perf.groupby('Dataset')

frames = {category : group for category, group in grouped}
df_CondMat = frames['data/CondMat.csv']
df_GenRel = frames['data/GenRel.csv']
df_ErdosReny = frames['data/ErdosRenyi.csv']
df_BarabasiAlbert = frames['data/BarabasiAlbert.csv']

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 20))
sns.barplot(data=df_CondMat, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][0])
sns.barplot(data=df_GenRel, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][1])
sns.barplot(data=df_BarabasiAlbert, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][2])
sns.barplot(data=df_ErdosReny, x='Percentage of data in training', y='Test Accuracy', hue='Model', ax=axes[0][3])
axes[0][0].set_ylim(0.9, 1)
axes[0][1].set_ylim(0.9, 1)
axes[0][2].set_ylim(0.7, 1)
axes[0][3].set_ylim(0.9, 1)
axes[0][0].set_title('CondMat')
axes[0][1].set_title('GenRel')
axes[0][2].set_title('BarabasiAlbert')
axes[0][3].set_title('ErdoRenyi')
axes[0][0].legend(loc='lower right')
axes[0][1].legend(loc='lower right')
axes[0][2].legend(loc='lower right')
axes[0][3].legend(loc='lower right')
sns.barplot(data=df_CondMat, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][0])
sns.barplot(data=df_GenRel, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][1])
sns.barplot(data=df_BarabasiAlbert, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][2])
sns.barplot(data=df_ErdosReny, x='Percentage of data in training', y='Train Accuracy', hue='Model', ax=axes[1][3])
axes[1][0].set_ylim(0.9, 1)
axes[1][1].set_ylim(0.9, 1)
axes[1][2].set_ylim(0.7, 1)
axes[1][3].set_ylim(0.9, 1)
axes[1][0].legend(loc='lower right')
axes[1][1].legend(loc='lower right')
axes[1][2].legend(loc='lower right')
axes[1][3].legend(loc='lower right')
fig.suptitle('Comparison of test and train accuracies across different models and datasets \n without densities of ego networks and shortest path features', fontsize=16)

# %%
model_perf = pd.read_csv('performance/neural_network_performance_all.csv')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 20))
sns.barplot(data=model_perf, x='Percentage of data in training', y='Test Accuracy', hue='Dataset', ax=axes[0])
sns.barplot(data=model_perf, x='Percentage of data in training', y='Train Accuracy', hue='Dataset', ax=axes[1])
axes[0].set_ylim(0.8, 1)
axes[1].set_ylim(0.8, 1)
axes[0].legend(loc='lower right')
axes[1].legend(loc='lower right')
fig.suptitle('Comparison of test and train accuracies across diferent datasets (using neural network) \n using all features', fontsize=16)

# %%
model_perf = pd.read_csv('performance/neural_network_performance_without_shortest_path.csv')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 20))
sns.barplot(data=model_perf, x='Percentage of data in training', y='Test Accuracy', hue='Dataset', ax=axes[0])
sns.barplot(data=model_perf, x='Percentage of data in training', y='Train Accuracy', hue='Dataset', ax=axes[1])
axes[0].set_ylim(0.5, 1)
axes[1].set_ylim(0.5, 1)
axes[0].legend(loc='lower right')
axes[1].legend(loc='lower right')
fig.suptitle('Comparison of test and train accuracies across different datasets \n without shortest path feature', fontsize=16)

# %%
model_perf = pd.read_csv('performance/neural_network_performance_without_ego.csv')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 20))
sns.barplot(data=model_perf, x='Percentage of data in training', y='Test Accuracy', hue='Dataset', ax=axes[0])
sns.barplot(data=model_perf, x='Percentage of data in training', y='Train Accuracy', hue='Dataset', ax=axes[1])
axes[0].set_ylim(0.8, 1)
axes[1].set_ylim(0.8, 1)
axes[0].legend(loc='lower right')
axes[1].legend(loc='lower right')
fig.suptitle('Comparison of test and train accuracies across different datasets (using neural network)  \n witouht densities of ego networks features', fontsize=16)

# %%
model_perf = pd.read_csv('performance/neural_network_performance_without_ego_and_shortest_path.csv')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 20))
sns.barplot(data=model_perf, x='Percentage of data in training', y='Test Accuracy', hue='Dataset', ax=axes[0])
sns.barplot(data=model_perf, x='Percentage of data in training', y='Train Accuracy', hue='Dataset', ax=axes[1])
axes[0].set_ylim(0.8, 1)
axes[1].set_ylim(0.8, 1)
axes[0].legend(loc='lower right')
axes[1].legend(loc='lower right')
fig.suptitle('Comparison of test and train accuracies across different datasets (using neural network)  \n witouht densities of ego networks and shortest path features', fontsize=16)

# %%
performance_all = pd.read_csv('performance/neural_network_performance_all.csv')
performance_wihtout_shortest_path = pd.read_csv('performance/neural_network_performance_without_shortest_path.csv')
performance_without_ego = pd.read_csv('performance/neural_network_performance_without_ego.csv')
performance_without_ego_and_shortest_path = pd.read_csv('performance/neural_network_performance_without_ego_and_shortest_path.csv')

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 20))
sns.barplot(data=performance_all, x='Percentage of data in training', y='Test Accuracy', hue='Dataset', ax=axes[0][0])
sns.barplot(data=performance_wihtout_shortest_path, x='Percentage of data in training', y='Test Accuracy', hue='Dataset', ax=axes[0][1])
sns.barplot(data=performance_without_ego, x='Percentage of data in training', y='Test Accuracy', hue='Dataset', ax=axes[0][2])
sns.barplot(data=performance_without_ego_and_shortest_path, x='Percentage of data in training', y='Test Accuracy', hue='Dataset', ax=axes[0][3])
axes[0][0].set_ylim(0.6, 1)
axes[0][1].set_ylim(0.6, 1)
axes[0][2].set_ylim(0.6, 1)
axes[0][3].set_ylim(0.6, 1)
axes[0][0].set_title('Performance with all features')
axes[0][1].set_title('Performance without \n shortest path feature')
axes[0][2].set_title('Performance without \n ego networks features')
axes[0][3].set_title('Performance without  \n ego networks \n and shortest path features')
axes[0][0].legend(loc='lower right')
axes[0][1].legend(loc='lower right')
axes[0][2].legend(loc='lower right')
axes[0][3].legend(loc='lower right')
sns.barplot(data=performance_all, x='Percentage of data in training', y='Train Accuracy', hue='Dataset', ax=axes[1][0])
sns.barplot(data=performance_wihtout_shortest_path, x='Percentage of data in training', y='Train Accuracy', hue='Dataset', ax=axes[1][1])
sns.barplot(data=performance_without_ego, x='Percentage of data in training', y='Train Accuracy', hue='Dataset', ax=axes[1][2])
sns.barplot(data=performance_without_ego_and_shortest_path, x='Percentage of data in training', y='Train Accuracy', hue='Dataset', ax=axes[1][3])
axes[1][0].set_ylim(0.6, 1)
axes[1][1].set_ylim(0.6, 1)
axes[1][2].set_ylim(0.6, 1)
axes[1][3].set_ylim(0.6, 1)
axes[1][0].legend(loc='lower right')
axes[1][1].legend(loc='lower right')
axes[1][2].legend(loc='lower right')
axes[1][3].legend(loc='lower right')
fig.suptitle('Comparison of test and train accuracies across different datasets using neural network \n combined for easier comparison between features used', fontsize=16)

# %% [markdown]
# Conclusions
#
#
# Models based on decision trees performed better as they can more easily use shortest path feature as value 1 leads to an edge exsisting, and anything else leads to edge not exsisting.
#
# Shortest path is also the most important feature for other models as we can see a dropoff in accuracy as we try to predict without it.
#
# Predictions made here are consistent with the source paper used: [Link Prediction in Social Networks using
# Computationally Efficient Topological Features](https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=9f3c2d5364aab82a24e24e56f6013cfc4c404e13)
